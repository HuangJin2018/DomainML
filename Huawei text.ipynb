# %%
import logging
import tensorflow as tf
import mlflow
import random
import pandas as pd
import numpy as np
import tqdm

import sys
import os

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

sys.argv.clear()
sys.argv.append("")

# %%
from src import config
from src.features import preprocessing,sequences,knowledge
from src.training import models
from src import refinement

# four types of knowledge for Huawei:
# gram, text, causal, log template(gram_logs)
experiment_config = config.ExperimentConfig()
experiment_config.model_type = "text"
experiment_config.sequence_type = "huawei_logs"

model_config = models.config.ModelConfig()
model_config.rnn_type: str = "gru"

# keep all other default configurations 
huawei_preprocessor_config = preprocessing.huawei.HuaweiPreprocessorConfig()
sequence_config = sequences.config.SequenceConfig()
knowledge_config = knowledge.config.KnowledgeConfig()
refinement_config = refinement.config.RefinementConfig()

# %%
def log_all_configs_to_mlflow():
    for config in [
        experiment_config,
        huawei_preprocessor_config,
        sequence_config,
        model_config,
        knowledge_config,
        refinement_config,
    ]:
        for config_name, config_value in vars(config).items():
            full_config_name = config.__class__.__name__ + config_name
            mlflow.log_param(full_config_name, str(config_value))

# %%
mlflow.set_experiment("Domain Guided Monitoring")
with mlflow.start_run() as run:
    run_id = run.info.run_id
logging.info("Starting run %s", run_id)
tf.random.set_seed(experiment_config.tensorflow_seed)
random.seed(experiment_config.random_seed)

# %% [markdown]
# ## Load Huawei sequences

# %%
sequence_preprocessor = preprocessing.ConcurrentAggregatedLogsPreprocessor(
    huawei_preprocessor_config,
)
sequence_column_name = sequence_preprocessor.sequence_column_name
sequence_df = sequence_preprocessor.load_data()

transformer = sequences.transformer.NextPartialSequenceTransformerFromDataframe(sequence_config)
metadata = transformer.collect_metadata(sequence_df, sequence_column_name)
# Out:
# /tmp/ipykernel_58444/3819484698.py:5: DtypeWarning: Columns (23,24,25,28) have mixed types.Specify dtype option on import or set low_memory=False.
#   sequence_df = sequence_preprocessor.load_data()
# Generating DRAIN clusters from log_df: 100%|███████████████| 152373/152373 [00:20<00:00, 7258.50it/s]
# Generating DRAIN clusters from log_df: 100%|███████████████| 152373/152373 [00:15<00:00, 9600.14it/s]
# Generating DRAIN clusters from log_df: 100%|████████████████████| 970/970 [00:00<00:00, 14211.82it/s]

# %% [markdown]
# ## Generate dataset

# %%
sequence_df_pkl_file: str = "data/sequences_df.pkl"
sequence_df.to_pickle(sequence_df_pkl_file)

train_sequences, test_sequences = transformer._split_train_test(sequence_df, sequence_column_name)

def generate(for_train):
    relevant_sequences = train_sequences if for_train else test_sequences
    for sequence in relevant_sequences:
        split_sequences = transformer._split_sequence(sequence)
        for split_sequence in split_sequences:
            transformer._translate_and_pad(split_sequence, metadata)
            yield split_sequence.x_vecs_stacked, split_sequence.y_vec

def generate_train():
    return generate(for_train=True)

def generate_test():
    return generate(for_train=False)

# %%
train_dataset = (
    tf.data.Dataset.from_generator(
        generate_train,
        output_types=(tf.float32, tf.float32),
    )
    .shuffle(
        experiment_config.dataset_shuffle_buffer,
        seed=experiment_config.dataset_shuffle_seed,
        reshuffle_each_iteration=True,
    )
    .batch(experiment_config.batch_size)
    .prefetch(tf.data.experimental.AUTOTUNE)
)

test_dataset = (
    tf.data.Dataset.from_generator(
        generate_test,
        output_types=(tf.float32, tf.float32),
    )
    .batch(experiment_config.batch_size)
    .prefetch(tf.data.experimental.AUTOTUNE)
)
# Out:
# 2022-05-30 09:05:35.408383: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-05-30 09:05:35.408404: E tensorflow/stream_executor/cuda/cuda_driver.cc:313] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-05-30 09:05:35.408419: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (hj-ubuntu): /proc/driver/nvidia/version does not exist
# 2022-05-30 09:05:35.408622: I tensorflow/core/platform/cpu_feature_guard.cc:143] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2022-05-30 09:05:35.436155: I tensorflow/core/platform/profile_utils/cpu_utils.cc:102] CPU Frequency: 2599990000 Hz
# 2022-05-30 09:05:35.437882: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7efe74000b60 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2022-05-30 09:05:35.437927: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version

# %% [markdown]
# ## Generate text

# %%
description_preprocessor = preprocessing.ConcurrentAggregatedLogsDescriptionPreprocessor(
    config = huawei_preprocessor_config
)

pd.set_option('display.max_columns', None) 
pd.set_option('display.max_rows', None) 
pd.set_option('max_colwidth',100)

# %% [markdown]
# ### Step 1 Load data

# %%
# Load log-only data 
huawei_df = sequence_preprocessor._load_log_only_data()
# Out:
# /home/jin/miniconda3/envs/healthcare-aiops/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (23,24,25,28) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Generating DRAIN clusters from log_df: 100%|███████████████| 152373/152373 [00:20<00:00, 7340.19it/s]
# Generating DRAIN clusters from log_df: 100%|███████████████| 152373/152373 [00:16<00:00, 9400.83it/s]
# Generating DRAIN clusters from log_df: 100%|████████████████████| 970/970 [00:00<00:00, 14921.86it/s]

# %%
'''
def _load_column_descriptions(
    self, huawei_df: pd.DataFrame, relevant_columns: Set[str]
) -> pd.DataFrame:
    http_descriptions = self._load_http_descriptions()
    column_descriptions = self._get_column_descriptions()
    description_records = []
    for column in relevant_columns:
        values = set(
            huawei_df[column].dropna().astype(str).replace(np.nan, "", regex=True)
        )
        values = set([str(x).lower() for x in values if len(str(x)) > 0])
        for value in tqdm(values, desc="Loading descriptions for column " + column):
            description = ""
            if column == "Hostname":
                name = value.rstrip("0123456789")
                number = value[len(name) :]
                description = name + " " + number
            elif column == "http_status":
                description = http_descriptions[value]
            else:
                description = " ".join(re.split("[,._\-\*]+", value))

            if column in column_descriptions:
                description = column_descriptions[column] + " " + description

            description_records.append(
                {"label": column + "#" + value, "description": description,},
            )

    return (
        pd.DataFrame.from_records(description_records)
        .drop_duplicates()
        .reset_index(drop=True)
    )
'''

description_df = description_preprocessor._load_column_descriptions(huawei_df, sequence_preprocessor.relevant_columns)
# Out:
# Loading descriptions for column python_module: 100%|█████████████| 95/95 [00:00<00:00, 212511.40it/s]
# Loading descriptions for column log_level: 100%|████████████████████| 3/3 [00:00<00:00, 64860.37it/s]
# Loading descriptions for column coarse_log_cluster_template: 100%|█| 482/482 [00:00<00:00, 71192.54it
# Loading descriptions for column fine_log_cluster_template: 100%|█| 1446/1446 [00:00<00:00, 156753.86i
# Loading descriptions for column http_status: 100%|███████████████| 11/11 [00:00<00:00, 167772.16it/s]
# Loading descriptions for column programname: 100%|███████████████| 24/24 [00:00<00:00, 195842.99it/s]
# Loading descriptions for column http_method: 100%|██████████████████| 4/4 [00:00<00:00, 32078.81it/s]
# Loading descriptions for column url_cluster_template: 100%|██████| 34/34 [00:00<00:00, 265067.54it/s]
# Loading descriptions for column Hostname: 100%|█████████████████████| 5/5 [00:00<00:00, 95760.37it/s]

# %%
description_df
# Out:
#                                                                                                     label  \
# 0                                                                   python_module#heat.engine.environment
# 1                                                                     python_module#neutron.common.config
# 2                                                    python_module#os_brick.initiator.connectors.remotefs
# 3                                                                          python_module#nova.compute.api
# 4                                                                      python_module#glance.api.v2.images
# 5                                                     python_module#neutron.plugins.ml2.drivers.type_flat
# 6                                             python_module#neutron.plugins.ml2.drivers.l2pop.mech_driver
# 7                                                                                python_module#cinder.rpc
# 8                                                                        python_module#glance.common.wsgi
# 9                                                          python_module#neutron.db.l3_agentschedulers_db
# 10                                                      python_module#oslo.messaging._drivers.impl_rabbit
# 11                                                    python_module#neutron.plugins.ml2.drivers.type_vlan
# 12                   python_module#neutron.plugins.ml2.drivers.openvswitch.agent.openflow.native.ofswitch
# 13                                                               python_module#oslo_db.sqlalchemy.engines
# 14                                                            python_module#cinder.scheduler.host_manager
# 15                                                         python_module#neutron.agent.securitygroups_rpc
# 16                                                                python_module#glance.common.store_utils
# 17                                                            python_module#neutron.agent.linux.interface
# 18                                                                          python_module#neutron_lib.rpc
# 19                                                                           python_module#cinder.service
# 20                                                            python_module#nova.compute.resource_tracker
# 21                                                                  python_module#nova.api.openstack.wsgi
# 22                                             python_module#neutron.plugins.ml2.extensions.port_security
# 23                                                                       python_module#nova.api.openstack
# 24                          python_module#neutron.plugins.ml2.drivers.openvswitch.agent.ovs_neutron_agent
# 25                                                                             python_module#neutron.wsgi
# 26                                                                   python_module#nova.conductor.manager
# 27                                                                       python_module#heat.engine.worker
# 28                                                                      python_module#nova.compute.claims
# 29                                                                   python_module#neutron.api.extensions
# 30                                                               python_module#oslo_service.periodic_task
# 31                 python_module#neutron.plugins.ml2.drivers.openvswitch.agent.openflow.native.ovs_bridge
# 32                                                                      python_module#oslo.privsep.daemon
# 33                                                                          python_module#neutron.service
# 34                                               python_module#keystone.access_rules_config.backends.json
# 35                                                                         python_module#nova.consoleauth
# 36                                                                   python_module#nova.virt.libvirt.host
# 37                                                              python_module#nova.scheduler.host_manager
# 38                                                                python_module#glance_store._drivers.rbd
# 39                                                                            python_module#neutron.quota
# 40                                                                         python_module#nova.virt.driver
# 41                                                                 python_module#neutron.agent.dhcp.agent
# 42                                                                    python_module#cinder.backup.manager
# 43                                                                   python_module#neutron.db.segments_db
# 44                                                                      python_module#nova.compute.rpcapi
# 45                                                             python_module#nova.servicegroup.drivers.db
# 46                     python_module#neutron.plugins.ml2.drivers.openvswitch.mech_driver.mech_openvswitch
# 47                                                                python_module#nova.metadata.wsgi.server
# 48                                                   python_module#neutron.agent.agent_extensions_manager
# 49                                                                 python_module#nova.virt.libvirt.driver
# 50                                                                           python_module#cinder.manager
# 51                                                             python_module#neutron.agent.metadata.agent
# 52                                                                 python_module#oslo.service.loopingcall
# 53                                                                     python_module#nova.compute.manager
# 54                                                                   python_module#neutron.agent.l3.agent
# 55                                                          python_module#neutron.quota.resource_registry
# 56                                                           python_module#nova.osapi_compute.wsgi.server
# 57                                                                     python_module#oslo_service.service
# 58                                                             python_module#oslo_middleware.catch_errors
# 59                                                             python_module#neutron.agent.common.ovs_lib
# 60                                                            python_module#keystonemiddleware.auth_token
# 61                                                            python_module#neutron.services.service_base
# 62                                                            python_module#neutron.db.agentschedulers_db
# 63                                                                  python_module#cinder.keymgr.migration
# 64                                                                     python_module#heat.common.profiler
# 65                                                           python_module#oslo_db.sqlalchemy.exc_filters
# 66                                                                      python_module#heat.engine.service
# 67                                                             python_module#neutron.plugins.ml2.managers
# 68                                                                     python_module#nova.scheduler.utils
# 69                                                                python_module#oslo_messaging.rpc.server
# 70                                                                  python_module#neutron.db.l3_hamode_db
# 71                                                                                python_module#nova.wsgi
# 72                                                                        python_module#nova.image.glance
# 73                                                                              python_module#py.warnings
# 74                                                                 python_module#oslo_db.sqlalchemy.utils
# 75                                                             python_module#nova.scheduler.client.report
# 76                                                                python_module#cinder.volume.drivers.rbd
# 77                                                                          python_module#oslo_config.cfg
# 78                                                                        python_module#cinder.cmd.backup
# 79                                                       python_module#neutron.agent.common.async_process
# 80                                                        python_module#keystone.server.flask.application
# 81                                                                                   python_module#os_vif
# 82                                                               python_module#neutron.plugins.ml2.plugin
# 83                                                       python_module#neutron.extensions.vlantransparent
# 84                                                                  python_module#os_ken.base.app_manager
# 85                                                                             python_module#nova.service
# 86                                                                    python_module#cinder.volume.manager
# 87                                                                     python_module#neutron.db.agents_db
# 88                                                                 python_module#keystone.common.profiler
# 89                                                                  python_module#neutron.common.profiler
# 90                                                                     python_module#eventlet.wsgi.server
# 91                                                  python_module#neutron.plugins.ml2.drivers.type_tunnel
# 92                                                             python_module#nova.virt.libvirt.imagecache
# 93                                                                          python_module#neutron.manager
# 94                                                              python_module#nova.console.websocketproxy
# 95                                                                                        log_level#error
# 96                                                                                      log_level#warning
# 97                                                                                         log_level#info
# 98    coarse_log_cluster_template#extension subnetsegmentidwritable not supported by any of loaded plu...
# 99    coarse_log_cluster_template#error during computemanagerupdate available resource remoteerror rem...
# 100                                           coarse_log_cluster_template#network vlan ranges ordereddict
# 101                                              coarse_log_cluster_template#initiating service * cleanup
# 102              coarse_log_cluster_template#25 nov 2019 * * * 0100 * v3 * * * * * * pythonkeystoneclient
# 103                                                       coarse_log_cluster_template#synchronizing state
# 104   coarse_log_cluster_template#active base files var lib nova instances base b7ea543d7e1d6e678a0988...
# 105                       coarse_log_cluster_template#portsecurityextensiondriver initialization complete
# 106                                          coarse_log_cluster_template#subnetpool is already registered
# 107   coarse_log_cluster_template#preparing filters for devices set u 2908dacf56bb41b3aeafa30321ba31de...
# 108                                     coarse_log_cluster_template#starting engine worker 14 in engine *
# 109   coarse_log_cluster_template#authtoken middleware is set with keystone authtokenservice token rol...
# 110                               coarse_log_cluster_template#wait called after thread killed cleaning up
# 111   coarse_log_cluster_template#deprecated option stores from group glance store is deprecated for r...
# 112                                     coarse_log_cluster_template#starting network * dhcp configuration
# 113                                coarse_log_cluster_template#imagevolume cache disabled for host * rbd1
# 114                               coarse_log_cluster_template#initializing extension driver port security
# 115      coarse_log_cluster_template#extension portresourcerequest not supported by any of loaded plugins
# 116                                              coarse_log_cluster_template#loaded extension externalnet
# 117   coarse_log_cluster_template#skipping arp spoofing rules for port * because it has port security ...
# 118                                coarse_log_cluster_template#25 nov 2019 16 * * * * * * * * * * * * * *
# 119             coarse_log_cluster_template#instance * took * seconds to * the instance on the hypervisor
# 120   coarse_log_cluster_template#failed reporting state messagingtimeout timed out waiting for a repl...
# 121                                                                coarse_log_cluster_template#hostname *
# 122   coarse_log_cluster_template#exception during message handling connectionerror error while readin...
# 123                 coarse_log_cluster_template#web server no directory listings web root usr share novnc
# 124   coarse_log_cluster_template#error during computemanager heal instance info cache messagingtimeou...
# 125                                coarse_log_cluster_template#ignoring old capability report from * rbd1
# 126   coarse_log_cluster_template#var lib kolla venv local lib python27 sitepackages oslo policy polic...
# 127                                                        coarse_log_cluster_template#loading plugin tag
# 128                                              coarse_log_cluster_template#loading plugin auto allocate
# 129   coarse_log_cluster_template#unexpected exception in api method connectfailure unable to establis...
# 130               coarse_log_cluster_template#instance * disk limit not specified defaulting to unlimited
# 131                         coarse_log_cluster_template#25 nov 2019 * * * * * * * * * * * * http 11 * * *
# 132   coarse_log_cluster_template#ports set u 8177e5e6e32c488c8b45e59351418b0d skipped changing status...
# 133   coarse_log_cluster_template#agent healthcheck found 3 dead agents out of 8 type last heartbeat h...
# 134                                                coarse_log_cluster_template#osapi compute listening on
# 135                                                  coarse_log_cluster_template#agent ha routers count 0
# 136                                                           coarse_log_cluster_template#* agent started
# 137   coarse_log_cluster_template#25 nov 2019 17 06 23 get v2 images limit 1000 id in 3a5ddb8ba7760944...
# 138             coarse_log_cluster_template#extension qosgatewayip not supported by any of loaded plugins
# 139   coarse_log_cluster_template#no config file found for access rules application credential access ...
# 140                      coarse_log_cluster_template#extension qos not supported by any of loaded plugins
# 141                                coarse_log_cluster_template#registered extension drivers port security
# 142                                  coarse_log_cluster_template#loaded type driver names flat vlan vxlan
# 143   coarse_log_cluster_template#traceback most recent call last file var lib kolla venv local lib py...
# 144   coarse_log_cluster_template#unexpected exception in api method connectfailure unable to establis...
# 145                               coarse_log_cluster_template#bridge brex has datapathid 00000025907ad2db
# 146   coarse_log_cluster_template#os heat softwaredeployments is hidden please use os heat softwaredep...
# 147   coarse_log_cluster_template#function neutronpluginsml2driversopenvswitchagentovs neutron agentov...
# 148   coarse_log_cluster_template#25 nov 2019 * * * 0100 get admin instances action row update table i...
# 149   coarse_log_cluster_template#process network ports iteration * agent port security group processe...
# 150                                          coarse_log_cluster_template#registered types flat vlan vxlan
# 151   coarse_log_cluster_template#unable to sync network state messagingtimeout timed out waiting for ...
# 152   coarse_log_cluster_template#get v20 ports device id 043a1ab694ca443c8589186167037847 device id f...
# 153                              coarse_log_cluster_template#driver initialization completed successfully
# 154   coarse_log_cluster_template#service * update failed pymysqlerroperationalerror 2003 can t connec...
# 155         coarse_log_cluster_template#connection failed errno * * retrying in * seconds error errno * *
# 156                                           coarse_log_cluster_template#initializing mechanism driver *
# 157                                      coarse_log_cluster_template#loaded extension allowedaddresspairs
# 158   coarse_log_cluster_template#error received from ovsdbclient monitor tcp interface name ofport ex...
# 159            coarse_log_cluster_template#instance * instance s host none is down deleting from database
# 160   coarse_log_cluster_template#unexpected exception in api method connectfailure unable to establis...
# 161                                           coarse_log_cluster_template#instance * vm * lifecycle event
# 162   coarse_log_cluster_template#var lib kolla venv local lib python27 sitepackages oslo policy polic...
# 163   coarse_log_cluster_template#configuration for devices up 2908dacf56bb41b3aeafa30321ba31de a3b34a...
# 164                                          coarse_log_cluster_template#loaded extension bindingextended
# 165              coarse_log_cluster_template#instance * took * seconds to deallocate network for instance
# 166   coarse_log_cluster_template#* amqp server on is unreachable * * * trying again in * seconds * * * *
# 167                                                   coarse_log_cluster_template#loaded agent extensions
# 168   coarse_log_cluster_template#failed reporting state messagingtimeout timed out waiting for a repl...
# 169   coarse_log_cluster_template#deprecated option deferred auth method from group default is depreca...
# 170                                          coarse_log_cluster_template#floatingip is already registered
# 171                                    coarse_log_cluster_template#starting consoleauth node version 1901
# 172              coarse_log_cluster_template#os magnum bay is hidden please use os magnum cluster instead
# 173                                  coarse_log_cluster_template#registered plugin user false * * * * * *
# 174   coarse_log_cluster_template#sql connection failed * attempts left dbconnectionerror pymysqlerrop...
# 175   coarse_log_cluster_template#os aodh combinationalarm is hidden os aodh combinationalarm is depre...
# 176   coarse_log_cluster_template#port * updated details profile network qos policy id none qos policy...
# 177                   coarse_log_cluster_template#delete v20 networks * http 11 status 204 len 173 time *
# 178                                   coarse_log_cluster_template#engine listener is stopped successfully
# 179   coarse_log_cluster_template#var lib kolla venv local lib python27 sitepackages oslo policy polic...
# 180   coarse_log_cluster_template#authorization failed the request you have made requires authenticati...
# 181                                                coarse_log_cluster_template#cleaning stale brint flows
# 182                      coarse_log_cluster_template#get v20 networks * * http 11 status 200 len * time *
# 183                                                coarse_log_cluster_template#loaded extension projectid
# 184               coarse_log_cluster_template#extension qosdefault not supported by any of loaded plugins
# 185   coarse_log_cluster_template#received a sync request from an unknown host * recreated its instanc...
# 186   coarse_log_cluster_template#deprecated option show multiple locations from group default is depr...
# 187   coarse_log_cluster_template#25 nov 2019 * * * 0100 get project http 11 200 * * mozilla 50 window...
# 188   coarse_log_cluster_template#automatically selected compute rpc version 51 from minimum service v...
# 189                                                     coarse_log_cluster_template#osprofiler is enabled
# 190                                     coarse_log_cluster_template#instance * claim successful on node *
# 191                                              coarse_log_cluster_template#flash security policy server
# 192                                           coarse_log_cluster_template#backup running with 1 processes
# 193   coarse_log_cluster_template#timeout in rpc method * * * * waiting for * seconds before next atte...
# 194                                      coarse_log_cluster_template#starting volume driver rbddriver 120
# 195   coarse_log_cluster_template#dbapierror exception wrapped from pymysqlerrinternalerror 1047 u wsr...
# 196                                              coarse_log_cluster_template#reserved cookies for * set *
# 197   coarse_log_cluster_template#unexpected exception in api method glanceconnectionfailed connection...
# 198      coarse_log_cluster_template#extension qosbwminimumingress not supported by any of loaded plugins
# 199                                            coarse_log_cluster_template#initializing extension manager
# 200                                  coarse_log_cluster_template#privsep process running with uid gid 0 0
# 201   coarse_log_cluster_template#error during computemanager sync scheduler instance info messagingti...
# 202                    coarse_log_cluster_template#connection event 0 reason connection to libvirt lost 0
# 203                                   coarse_log_cluster_template#spawned new privsep daemon via rootwrap
# 204                                              coarse_log_cluster_template#router is already registered
# 205   coarse_log_cluster_template#privsep log var lib kolla venv local lib python27 sitepackages psyco...
# 206             coarse_log_cluster_template#delete v20 securitygroups * http 11 status 204 len 173 time *
# 207   coarse_log_cluster_template#instance * is not being actively managed by this compute host but ha...
# 208   coarse_log_cluster_template#removing base or swap file var lib nova instances base b7ea543d7e1d6...
# 209                                           coarse_log_cluster_template#loading etc heat environmentd *
# 210   coarse_log_cluster_template#25 nov 2019 * * * 0100 * * * http 11 200 * * http wally113cittuberli...
# 211       coarse_log_cluster_template#get v21 * servers detail marker * http 11 status 200 len 413 time *
# 212               coarse_log_cluster_template#host * has more disk space than database expected * gb * gb
# 213                     coarse_log_cluster_template#registered mechanism drivers openvswitch l2population
# 214   coarse_log_cluster_template#instance 97d0d2171fed411ebc80deb4840076b7 error from last host wally...
# 215   coarse_log_cluster_template#preparing filters for devices set u 2908dacf56bb41b3aeafa30321ba31de...
# 216          coarse_log_cluster_template#extension vlantransparent not supported by any of loaded plugins
# 217                     coarse_log_cluster_template#driver post rpc initialization completed successfully
# 218              coarse_log_cluster_template#registered wildcard mapping user false os quantum os neutron
# 219                           coarse_log_cluster_template#configured extension driver names port security
# 220                                                coarse_log_cluster_template#tenant network types vxlan
# 221   coarse_log_cluster_template#port 8177e5e6e32c488c8b45e59351418b0d was not found on the integrati...
# 222     coarse_log_cluster_template#os nova floatingip is hidden please use os neutron floatingip instead
# 223                          coarse_log_cluster_template#25 nov 2019 * * * 0100 * * * * * * * * * * * * *
# 224   coarse_log_cluster_template#error contacting glance server http for get retrying communicationer...
# 225   coarse_log_cluster_template#configuration for devices up 2908dacf56bb41b3aeafa30321ba31de u a3b3...
# 226                       coarse_log_cluster_template#http exception thrown instance * could not be found
# 227   coarse_log_cluster_template#not migrating encryption keys because the confkeymanager s fixed key...
# 228   coarse_log_cluster_template#get v20 ports device id d1aa6fb8e69e496794aceefa39f0d522 device id 0...
# 229   coarse_log_cluster_template#endpoint with ip already exists dbduplicateentry pymysqlerrintegrity...
# 230   coarse_log_cluster_template#25 nov 2019 * * * 0100 put allocations * http 11 204 * * keystoneaut...
# 231                                                   coarse_log_cluster_template#privsep daemon starting
# 232                  coarse_log_cluster_template#get v20 quotas * details http 11 status 200 len * time *
# 233   coarse_log_cluster_template#os heat structureddeployments is hidden please use os heat structure...
# 234                                 coarse_log_cluster_template#security group rule is already registered
# 235                        coarse_log_cluster_template#get v20 quotas * http 11 status 200 len 373 time *
# 236                               coarse_log_cluster_template#loading compute driver libvirtlibvirtdriver
# 237                                                    coarse_log_cluster_template#loading plugin flavors
# 238                                         coarse_log_cluster_template#removing os heat * from os heat *
# 239           coarse_log_cluster_template#get v20 floatingips tenant id * http 11 status 200 len * time *
# 240   coarse_log_cluster_template#unexpected exception in api method connectfailure unable to establis...
# 241                   coarse_log_cluster_template#extension qosfip not supported by any of loaded plugins
# 242                                                      coarse_log_cluster_template#stopping wsgi server
# 243   coarse_log_cluster_template#since image size is zero we will be doing resizebeforewrite for each...
# 244   coarse_log_cluster_template#extension segmentspeersubnethostroutes not supported by any of loade...
# 245   coarse_log_cluster_template#osprofiler is enabled it means that person who knows any of hmac key...
# 246                                                           coarse_log_cluster_template#started child *
# 247                                    coarse_log_cluster_template#loaded extension standardattrrevisions
# 248   coarse_log_cluster_template#error during computemanager sync power states remoteerror remote err...
# 249                            coarse_log_cluster_template#os neutron pool is hidden use lbaas v2 instead
# 250   coarse_log_cluster_template#number of active agents lower than max l3 agents per router l3 agent...
# 251                                            coarse_log_cluster_template#updating bandwidth usage cache
# 252   coarse_log_cluster_template#25 nov 2019 * * * 0100 get i18n js horizon openstack dashboard heat ...
# 253                                        coarse_log_cluster_template#loaded extension availability zone
# 254   coarse_log_cluster_template#os neutron extraroute is unsupported use this resource at your own risk
# 255                          coarse_log_cluster_template#post v21 * servers http 11 status * len * time *
# 256                                 coarse_log_cluster_template#get v21 http 11 status 200 len 788 time *
# 257                                coarse_log_cluster_template#registered plugin user false * * * class *
# 258   coarse_log_cluster_template#25 nov 2019 * * * 0100 get * * * * * * * * * * * keystoneauth1 3131 ...
# 259                                              coarse_log_cluster_template#synchronizing state complete
# 260                                                   coarse_log_cluster_template#device * already exists
# 261               coarse_log_cluster_template#* reconnected to amqp server on via amqp client with port *
# 262                                     coarse_log_cluster_template#var lib kolla venv bin * version 1402
# 263   coarse_log_cluster_template#base or swap file too young to remove var lib nova instances base b7...
# 264   coarse_log_cluster_template#image 5ddb8ba77609443eab6002b3656b334b at var lib nova instances bas...
# 265   coarse_log_cluster_template#error during computemanager sync scheduler instance info remoteerror...
# 266                                    coarse_log_cluster_template#engine service is stopped successfully
# 267                                             coarse_log_cluster_template#security group rule updated *
# 268                      coarse_log_cluster_template#get v20 ports * id * http 11 status 200 len * time *
# 269   coarse_log_cluster_template#25 nov 2019 16 * * 0100 get i18n js horizon openstack dashboard heat...
# 270   coarse_log_cluster_template#caught error error while reading from socket u connection closed by ...
# 271   coarse_log_cluster_template#ofport 1 for vif 8177e5e6e32c488c8b45e59351418b0d is not a positive ...
# 272               coarse_log_cluster_template#os designate domain is hidden use os designate zone instead
# 273   coarse_log_cluster_template#get v20 ports device id bc792723bb04438fbc40fc355bce4e2f device id 9...
# 274                                         coarse_log_cluster_template#recovered model server connection
# 275   coarse_log_cluster_template#os nova floatingipassociation is hidden please use os neutron floati...
# 276                                coarse_log_cluster_template#registered plugin user false * * * * * * *
# 277   coarse_log_cluster_template#skipping period l3 agent status check because automatic router resch...
# 278                                        coarse_log_cluster_template#stopping engine worker in engine *
# 279   coarse_log_cluster_template#get v21 fb6b46e184a14d519f0a3e6013967188 servers detail all tenants ...
# 280   coarse_log_cluster_template#error contacting glance server http for get done trying communicatio...
# 281   coarse_log_cluster_template#unexpected error while reporting service status dbconnectionerror py...
# 282              coarse_log_cluster_template#instance * deletion of var lib nova instances * del complete
# 283   coarse_log_cluster_template#failed reporting state messagingtimeout timed out waiting for a repl...
# 284                                      coarse_log_cluster_template#starting scheduler node version 1901
# 285   coarse_log_cluster_template#var lib kolla venv local lib python27 sitepackages oslo policy polic...
# 286   coarse_log_cluster_template#var lib kolla venv local lib python27 sitepackages oslo policy polic...
# 287                                                    coarse_log_cluster_template#vxlan id ranges 1 1000
# 288             coarse_log_cluster_template#extension l2 adjacency not supported by any of loaded plugins
# 289                                        coarse_log_cluster_template#disabled vlantransparent extension
# 290                                                     coarse_log_cluster_template#metadata listening on
# 291                                                     coarse_log_cluster_template#loading plugin router
# 292                                           coarse_log_cluster_template#instance * total * * * used * *
# 293     coarse_log_cluster_template#get v20 securitygroups tenant id * http 11 status 200 len 2634 time *
# 294                                            coarse_log_cluster_template#connection event 1 reason none
# 295   coarse_log_cluster_template#unexpected error while reporting service status remoteerror remote e...
# 296   coarse_log_cluster_template#var lib kolla venv local lib python27 sitepackages oslo policy polic...
# 297                   coarse_log_cluster_template#os neutron healthmonitor is hidden use lbaas v2 instead
# 298       coarse_log_cluster_template#connection failed timed out retrying in * seconds timeout timed out
# 299     coarse_log_cluster_template#get v20 ports fields id tenant id * http 11 status 200 len 210 time *
# 300   coarse_log_cluster_template#agent healthcheck found 3 dead agents out of 8 type last heartbeat h...
# 301   coarse_log_cluster_template#device 724dbf91efbc4b0a962263413fe8b881 not defined on plugin or bin...
# 302   coarse_log_cluster_template#instance * during sync power state the instance has a pending task *...
# 303                    coarse_log_cluster_template#loaded mechanism driver names openvswitch l2population
# 304                                           coarse_log_cluster_template#instance * terminating instance
# 305                        coarse_log_cluster_template#sigterm received capping rpc timeout by 10 seconds
# 306   coarse_log_cluster_template#an error occurred during processing the request get v20 networks ten...
# 307   coarse_log_cluster_template#var lib kolla venv local lib python27 sitepackages oslo policy polic...
# 308                                  coarse_log_cluster_template#loaded vif plugins ovs linux bridge noop
# 309                   coarse_log_cluster_template#instantiating app os kenappofctlservice of ofctlservice
# 310   coarse_log_cluster_template#25 nov 2019 * * * 0100 post v3 auth tokens http 11 201 * * * * keyst...
# 311                                               coarse_log_cluster_template#service * cleanup completed
# 312   coarse_log_cluster_template#get v21 fb6b46e184a14d519f0a3e6013967188 * * * http 11 status 200 le...
# 313   coarse_log_cluster_template#25 nov 2019 * * * 0100 get * * * * * * * * * mozilla 50 windows nt 1...
# 314   coarse_log_cluster_template#osprofiler is enabled traces provided from the profiler can only be ...
# 315                                      coarse_log_cluster_template#neutron service started listening on
# 316   coarse_log_cluster_template#privsep process running with capabilities eff prm inh cap chown cap ...
# 317   coarse_log_cluster_template#25 nov 2019 * * * 0100 * * * * * * * * * * * keystoneauth1 3131 pyth...
# 318   coarse_log_cluster_template#unexpected error during heartbeart thread processing retrying error ...
# 319   coarse_log_cluster_template#var lib kolla venv local lib python27 sitepackages oslo policy polic...
# 320   coarse_log_cluster_template#deprecated option firewall driver from group default is deprecated f...
# 321   coarse_log_cluster_template#25 nov 2019 * * * 0100 get http 11 302 * mozilla 50 windows nt 100 w...
# 322                    coarse_log_cluster_template#extension trunk not supported by any of loaded plugins
# 323                        coarse_log_cluster_template#get v20 subnets http 11 status 200 len 1434 time *
# 324                                       coarse_log_cluster_template#25 nov 2019 * * * * * * * * * * * *
# 325   coarse_log_cluster_template#l2agent cannot contact neutron server check connectivity to neutron ...
# 326   coarse_log_cluster_template#failed to schedule instances remoteerror remote error connectionerro...
# 327   coarse_log_cluster_template#while synchronizing instance power states found * instances in the d...
# 328   coarse_log_cluster_template#failed to delete image 40a235f7089a4573b3dac62667871d04 in store fro...
# 329   coarse_log_cluster_template#removable base files var lib nova instances base b7ea543d7e1d6e678a0...
# 330                      coarse_log_cluster_template#got portsecurity extension from driver port security
# 331   coarse_log_cluster_template#port a3b34a63341f4bd4a6c55f4c4cd57bc9 updated details profile networ...
# 332   coarse_log_cluster_template#instance 2bfaa0e8d73847999082db20177170b7 failed to deallocate netwo...
# 333   coarse_log_cluster_template#wsrep running position recovery with disablelogerror pidfile var lib...
# 334   coarse_log_cluster_template#os heat harestarter is hidden the harestarter resource type has been...
# 335                                   coarse_log_cluster_template#starting cindervolume node version 1400
# 336   coarse_log_cluster_template#the novaconsoleauth service is deprecated as console token authoriza...
# 337   coarse_log_cluster_template#finished a router update for 35117c4aeee6487092b5ab6a3cda92cd update...
# 338                                                                 coarse_log_cluster_template#listen on
# 339                                    coarse_log_cluster_template#loading plugin network ip availability
# 340                               coarse_log_cluster_template#get v21 * * http 11 status 200 len * time *
# 341   coarse_log_cluster_template#25 nov 2019 18 * * get v2 images limit 1000 id in 3a5ddb8ba77609443e...
# 342                                             coarse_log_cluster_template#agent out of sync with plugin
# 343                                                        coarse_log_cluster_template#starting * workers
# 344                                                 coarse_log_cluster_template#websocket server settings
# 345                      coarse_log_cluster_template#successfully reported state after a previous failure
# 346                                 coarse_log_cluster_template#bridge brex datapathid 0x00000025907ad2db
# 347          coarse_log_cluster_template#extension dataplanestatus not supported by any of loaded plugins
# 348                                        coarse_log_cluster_template#volume service is down host * rbd1
# 349   coarse_log_cluster_template#instance * an error occurred while refreshing the network cache conn...
# 350                     coarse_log_cluster_template#25 nov 2019 * * * 0100 get v3 * * * http 11 200 * * *
# 351   coarse_log_cluster_template#get v20 ports device id 70c3411d6c72459cbc4257cf22603cc6 device id d...
# 352                                                 coarse_log_cluster_template#cleaning stale brex flows
# 353   coarse_log_cluster_template#could not find domain default domainnotfound could not find domain d...
# 354   coarse_log_cluster_template#25 nov 2019 * * * 0100 post v3 auth tokens http 11 201 * * * keyston...
# 355                                            coarse_log_cluster_template#initializing driver for type *
# 356   coarse_log_cluster_template#agent on host wally113 did not supply agent restarted information in...
# 357                             coarse_log_cluster_template#determined volume db was not empty at startup
# 358   coarse_log_cluster_template#timeout in rpc method get host ha router count waiting for 24 second...
# 359   coarse_log_cluster_template#unexpected exception in api method internalservererror the server ha...
# 360   coarse_log_cluster_template#deprecated option url from group neutron is deprecated for removal e...
# 361                                 coarse_log_cluster_template#modular l2 plugin initialization complete
# 362      coarse_log_cluster_template#preparing filters for devices set u a3b34a63341f4bd4a6c55f4c4cd57bc9
# 363   coarse_log_cluster_template#agent healthcheck found 2 dead agents out of 8 type last heartbeat h...
# 364                              coarse_log_cluster_template#recovered from being unable to report status
# 365   coarse_log_cluster_template#25 nov 2019 * * * 0100 get * * * * http 11 200 * * http wally113citt...
# 366   coarse_log_cluster_template#running privsep helper sudo neutronrootwrap etc neutron rootwrapconf...
# 367   coarse_log_cluster_template#unexpected error while reporting service status remoteerror remote e...
# 368                                     coarse_log_cluster_template#assigning * as local vlan for netid *
# 369                                        coarse_log_cluster_template#instance * instance * successfully
# 370   coarse_log_cluster_template#automatically selected cinderbackup * version * as minimum service v...
# 371   coarse_log_cluster_template#l3agent cannot contact neutron server to retrieve ha router count ch...
# 372   coarse_log_cluster_template#os glance image is deprecated creating a glance image based on an ex...
# 373   coarse_log_cluster_template#sql connection failed * attempts left dbconnectionerror pymysqlerrop...
# 374                                                 coarse_log_cluster_template#instance * creating image
# 375   coarse_log_cluster_template#get v20 networks tenant id * shared false http 11 status * len * time *
# 376             coarse_log_cluster_template#post v21 * servers * action http 11 status 202 len 403 time *
# 377           coarse_log_cluster_template#instance * deleting instance files var lib nova instances * del
# 378   coarse_log_cluster_template#port * updated details profile network qos policy id none qos policy...
# 379   coarse_log_cluster_template#instance * instance failed to spawn connectfailure unable to establi...
# 380                                                    coarse_log_cluster_template#refresh firewall rules
# 381                   coarse_log_cluster_template#open vswitch agent s supported vnic types normal direct
# 382                               coarse_log_cluster_template#get v21 * * * http 11 status * len * time *
# 383                                             coarse_log_cluster_template#bridge brtun has datapathid *
# 384                                                 coarse_log_cluster_template#loaded extension subnet *
# 385                coarse_log_cluster_template#configured mechanism driver names openvswitch l2population
# 386   coarse_log_cluster_template#http exception thrown unexpected api error please report this at htt...
# 387   coarse_log_cluster_template#failed to save allocation for * got http 409 errors status 409 reque...
# 388                                                   coarse_log_cluster_template#loaded extension router
# 389                   coarse_log_cluster_template#configuration for devices up and devices down completed
# 390                    coarse_log_cluster_template#get v20 extensions http 11 status 200 len 10724 time *
# 391   coarse_log_cluster_template#* amqp server on is unreachable timed out trying again in * seconds ...
# 392                                             coarse_log_cluster_template#bridge brint has datapathid *
# 393   coarse_log_cluster_template#var lib kolla venv local lib python27 sitepackages oslo policy polic...
# 394   coarse_log_cluster_template#image 74a117412ea8457b9a1925988e46695c could not be deleted because ...
# 395                                            coarse_log_cluster_template#port * has lost its vlan tag *
# 396                                                           coarse_log_cluster_template#logging enabled
# 397   coarse_log_cluster_template#os magnum baymodel is hidden please use os magnum clustertemplate in...
# 398            coarse_log_cluster_template#extension qosrulesalias not supported by any of loaded plugins
# 399   coarse_log_cluster_template#25 nov 2019 * * * 0100 get * * * * * * * * mozilla 50 windows nt 100...
# 400   coarse_log_cluster_template#configuration for devices up u 2908dacf56bb41b3aeafa30321ba31de u a3...
# 401                                                  coarse_log_cluster_template#loading plugin revisions
# 402   coarse_log_cluster_template#did not find expected name stdattrs common in var lib kolla venv loc...
# 403   coarse_log_cluster_template#25 nov 2019 * * * 0100 get allocation candidates limit 1000 resource...
# 404   coarse_log_cluster_template#deprecated option default store from group glance store is deprecate...
# 405          coarse_log_cluster_template#default provider is not specified for service type l3 router nat
# 406   coarse_log_cluster_template#a recoverable connection channel error occurred trying to reconnect ...
# 407   coarse_log_cluster_template#get v21 fb6b46e184a14d519f0a3e6013967188 http 11 status 404 len 382 ...
# 408   coarse_log_cluster_template#unknown base file var lib nova instances base b7ea543d7e1d6e678a0988...
# 409                                  coarse_log_cluster_template#cleaning up incomplete backup operations
# 410                        coarse_log_cluster_template#put v20 quotas * http 11 status 200 len 372 time *
# 411                                   coarse_log_cluster_template#starting cinderbackup node version 1400
# 412                                                                   coarse_log_cluster_template#in exit
# 413   coarse_log_cluster_template#skipping periodic task discover hosts in cells because its interval ...
# 414   coarse_log_cluster_template#increasing timeout for * * * * calls to 120 seconds restart the agen...
# 415   coarse_log_cluster_template#error from libvirt while getting description of * error code 42 doma...
# 416   coarse_log_cluster_template#25 nov 2019 17 06 19 get v2 images limit 1000 sort key created at so...
# 417   coarse_log_cluster_template#25 nov 2019 * * * 0100 * * * * * * * * * * * * mozilla 50 windows nt...
# 418   coarse_log_cluster_template#starting router update for 35117c4aeee6487092b5ab6a3cda92cd action 3...
# 419   coarse_log_cluster_template#function cinderserviceservicereport state run outlasted interval by ...
# 420                                    coarse_log_cluster_template#loaded extension networkipavailability
# 421                                 coarse_log_cluster_template#http v21 * servers returned with http 500
# 422                                     coarse_log_cluster_template#finished network * dhcp configuration
# 423      coarse_log_cluster_template#initializing rpc dependent components of volume driver rbddriver 120
# 424                                coarse_log_cluster_template#ml2 flattypedriver initialization complete
# 425                                                  coarse_log_cluster_template#loading plugin timestamp
# 426                      coarse_log_cluster_template#os neutron poolmember is hidden use lbaas v2 instead
# 427   coarse_log_cluster_template#* failed to update inventory to vcpu allocation ratio 160 total 8 re...
# 428                                           coarse_log_cluster_template#loaded extension extra dhcp opt
# 429   coarse_log_cluster_template#instance 13989393e26d4f76a409de216c59d631 instance failed to spawn c...
# 430                       coarse_log_cluster_template#25 nov 2019 * * * post v2 images http 11 201 1002 *
# 431                                                        coarse_log_cluster_template#loaded extension *
# 432   coarse_log_cluster_template#25 nov 2019 * * * 0100 get i18n js horizon openstack dashboard heat ...
# 433                                    coarse_log_cluster_template#vlantypedriver initialization complete
# 434   coarse_log_cluster_template#function novaservicegroupdriversdbdbdriver report state run outlaste...
# 435                                               coarse_log_cluster_template#loaded extension extraroute
# 436   coarse_log_cluster_template#increasing timeout for get host ha router count calls to 120 seconds...
# 437   coarse_log_cluster_template#25 nov 2019 * * * 0100 * * * * * * * * * keystoneauth1 3131 pythonre...
# 438   coarse_log_cluster_template#25 nov 2019 16 * * get v2 images * * * * * * sort key created at sor...
# ...
# 1956  error connecting to ceph cluster timedout errno 110 error connecting to the cluster 20191125 15 ...
# 1957                                                25 nov 2019 16 22   get v2 images   http 11 200 851
# 1958                                                                   starting compute node version 1901
# 1959  unexpected exception in api method httpinternalservererror http httpinternalservererror 20191125...
# 1960                                             25 nov 2019 18 30   delete v2 images   http 11 204 213
# 1961                                                            agent caught sigterm quitting daemon loop
# 1962  registered plugin user false os neutron routerinterface class heatengineresourcesopenstackneutro...
# 1963                                             25 nov 2019 17 18   delete v2 images   http 11 204 213
# 1964                                       wsgi starting up on http var lib neutron keepalivedstatechange
# 1965                            25 nov 2019 20 36   0100 delete v3     http 11 204   pythonkeystoneclient
# 1966  registered plugin user false os heat softwaredeployment class heatengineresourcesopenstackheatso...
# 1967  25 nov 2019 16     0100 get resource providers     http 11 200     novacompute keystoneauth1 313...
# 1968                                               25 nov 2019 16 16   get v2 images   http 11 200 1133
# 1969  privsep process running with capabilities eff prm inh cap dac override cap dac read search cap n...
# 1970                                                                       loaded extension securitygroup
# 1971                                               25 nov 2019 17 25   get v2 images   http 11 200 1133
# 1972  dnsmasqcapsrefreshinternal 733 cannot check dnsmasq binary usr sbin dnsmasq no such file or dire...
# 1973  libvirt version 500 package 1ubuntu23 cloud0 openstack ubuntu testing bot openstacktestingbot ub...
# 1974                                                                             wsgi starting up on http
# 1975                                                                                    hostname wally117
# 1976  25 nov 2019 17     0100 post v3 auth tokens http 11 201         keystonemiddlewareauth token 600...
# 1977  error during volumemanagerpublish service capabilities volumebackendapiexception bad or unexpect...
# 1978                                                                               loaded extension agent
# 1979  get v21 28f0f4b4c7474524b56e9768cb83f84b servers 0d4549e2fc7b4e96ba311ed3783f4371 http 11 status...
# 1980                                                25 nov 2019 17   45 get v2 images   http 11 200 851
# 1981                                             25 nov 2019   28 07 delete v2 images   http 11 204 213
# 1982      get v20 ports device id   device id   device id   device id   http 11 status 200 len 210 time
# 1983                   automatically selected cindervolume objects version 137 as minimum service version
# 1984                                                                              wsgi server has stopped
# 1985                                                                      loaded extension netmtuwritable
# 1986  registered plugin user false os neutron securitygroup class heatengineresourcesopenstackneutrons...
# 1987                                                              loading app os kencontrollerofp handler
# 1988  unexpected exception in api method connectfailure unable to establish connection to http v20 net...
# 1989                                                25 nov 2019 17   37 get v2 images   http 11 200 851
# 1990                                             25 nov 2019 17 46   delete v2 images   http 11 204 213
# 1991                                       unique keys not in sort keys the sorting order may be unstable
# 1992                                                                         child   exited with status 0
# 1993              25 nov 2019 18 50   delete v2 images 74a117412ea8457b9a1925988e46695c http 11 409 512
# 1994  registered plugin user false os keystone grouproleassignment class heatengineresourcesopenstackk...
# 1995  os neutron routergateway is hidden use the external gateway info property in the router resource...
# 1996                                                                                   dhcp agent started
# 1997                                                25 nov 2019 17 37   get v2 images   http 11 200 851
# 1998  25 nov 2019 15 48 48 0100 post v3 auth tokens http 11       keystoneauth1 3131 pythonrequests 22...
# 1999                                             25 nov 2019 18 05   delete v2 images   http 11 204 213
# 2000  port 968f08cd41784a28ab32781d3b6c9afe updated details profile network qos policy id none qos pol...
# 2001  25 nov 2019 19     0100 post v3 auth tokens http 11       keystoneauth1 3131 pythonrequests 2210...
# 2002  registered plugin user false os barbican certificatecontainer class heatengineresourcesopenstack...
# 2003                                        instance   memory limit not specified defaulting to unlimited
# 2004                                             extension logging not supported by any of loaded plugins
# 2005                                                                              loading core plugin ml2
# 2006                                               25 nov 2019 18 12   get v2 images   http 11 200 1133
# 2007                                                                                     started child 21
# 2008  registered plugin user false os keystone endpoint class heatengineresourcesopenstackkeystoneendp...
# 2009                                             25 nov 2019 18 21   delete v2 images   http 11 204 213
# 2010                                             25 nov 2019 17 38   delete v2 images   http 11 204 213
# 2011                                                25 nov 2019 16 38   get v2 images   http 11 200 851
# 2012                                                                 security group is already registered
# 2013                                                25 nov 2019   45 30 get v2 images   http 11 200 851
# 2014                                                25 nov 2019 16 30   get v2 images   http 11 200 851
# 2015                        automatically selected cinderbackup rpc version 21 as minimum service version
# 2016  25 nov 2019 16     0100 get admin   http 11 200     mozilla 50 windows nt 100 win64 x64 appleweb...
# 2017                            removing os heat structureddeployments from os heat structureddeployments
# 2018    amqp server on is unreachable errno 104 connection reset by peer trying again in 1 seconds err...
# 2019                                               25 nov 2019 17 58   get v2 images   http 11 200 1133
# 2020  registered plugin user false os magnum clustertemplate class heatengineresourcesopenstackmagnumc...
# 2021                                               25 nov 2019 16 59   get v2 images   http 11 200 1133
# 2022                                               25 nov 2019 18 32   get v2 images   http 11 200 1133
# 2023                                               get v21   oskeypairs http 11 status 200 len 414 time
# 2024  service   update failed pymysqlerroperationalerror 2003 can t connect to mysql server on errno 1...
# 2025  unexpected exception in api method connectfailure unable to establish connection to http v20 por...
# 2026                                                                               HTTP status no content
# 2027                                                                                HTTP status not found
# 2028                                                                             HTTP status not modified
# 2029                                                                             HTTP status unauthorized
# 2030                                                                                       HTTP status ok
# 2031                                                                    HTTP status internal server error
# 2032                                                                                 HTTP status conflict
# 2033                                                                         HTTP status multiple choices
# 2034                                                                                 HTTP status continue
# 2035                                                                                  HTTP status created
# 2036                                                                                    HTTP status found
# 2037                                                                          Program name horizon access
# 2038                                                                        Program name nova consoleauth
# 2039                                                                        Program name cinder scheduler
# 2040                                                            Program name keystone apache admin access
# 2041                                                                           Program name cinder backup
# 2042                                                                                Program name nova api
# 2043                                                           Program name keystone apache public access
# 2044                                                                          Program name nova conductor
# 2045                                                                          Program name neutron server
# 2046                                                                            Program name nova compute
# 2047                                                                          Program name nova scheduler
# 2048                                                                    Program name placement api access
# 2049                                                               Program name neutron openvswitch agent
# 2050                                                                  Program name neutron metadata agent
# 2051                                                                                Program name keystone
# 2052                                                                              Program name glance api
# 2053                                                                         Program name nova novncproxy
# 2054                                                                       Program name cinder api access
# 2055                                                                                 Program name mariadb
# 2056                                                                           Program name cinder volume
# 2057                                                                      Program name neutron dhcp agent
# 2058                                                                             Program name heat engine
# 2059                                                                                 Program name libvirt
# 2060                                                                        Program name neutron l3 agent
# 2061                                                                                   HTTP method delete
# 2062                                                                                      HTTP method get
# 2063                                                                                      HTTP method put
# 2064                                                                                     HTTP method post
# 2065                                                                  Url Cluster v3 domains name default
# 2066                                                         Url Cluster resource providers   allocations
# 2067                             Url Cluster v3 projects   users   roles 45b34dafb0d745a8873f482c0c32ff15
# 2068                                                                              Url Cluster header next
# 2069                                                              Url Cluster resource providers   traits
# 2070                                                                       Url Cluster v3 domains default
# 2071                                                         Url Cluster static dashboard img favicon ico
# 2072                                                                               Url Cluster v3 users
# 2073    Url Cluster v3 fb6b46e184a14d519f0a3e6013967188 limits tenant id fb6b46e184a14d519f0a3e6013967188
# 2074                                                                          Url Cluster admin instances
# 2075                                                                           Url Cluster admin networks
# 2076                                                                                   Url Cluster header
# 2077                                                                                 Url Cluster v3 roles
# 2078                                       Url Cluster v3 users 77c8e03644c64f52a2d824eac5e4c500 projects
# 2079                              Url Cluster admin instances 9f5ac677 522a 40c8 ac55 0bea963af100 rescue
# 2080                                                                          Url Cluster auth login next
# 2081                                       Url Cluster i18n js horizon openstack dashboard heat dashboard
# 2082                                                         Url Cluster resource providers   inventories
# 2083                                                                                 Url Cluster v3 users
# 2084                                                                               Url Cluster auth login
# 2085                                                                            Url Cluster allocations
# 2086                                                             Url Cluster resource providers in tree
# 2087                                       Url Cluster v3 fb6b46e184a14d519f0a3e6013967188 volumes detail
# 2088                                                                              Url Cluster v3 projects
# 2089    Url Cluster allocation candidates limit 1000 resources disk gb 3a40 2cmemory mb 3a4096 2cvcpu 3a2
# 2090                            Url Cluster v3 fb6b46e184a14d519f0a3e6013967188 os volume transfer detail
# 2091                                                                                       Url Cluster v3
# 2092                                                                                  Url Cluster project
# 2093                                                                        Url Cluster admin hypervisors
# 2094                                                                           Url Cluster v3 auth tokens
# 2095                                                          Url Cluster resource providers   aggregates
# 2096                                                                            Url Cluster v3 projects
# 2097                               Url Cluster admin instances action row update table instances obj id
# 2098                                                                        Url Cluster project instances
# 2099                                                                                  Host name wally 123
# 2100                                                                                  Host name wally 117
# 2101                                                                                  Host name wally 124
# 2102                                                                                  Host name wally 122
# 2103                                                                                  Host name wally 113

# %% [markdown]
# ### Step 2 Build knowledge from daraframe

# %%
description_knowledge = knowledge.DescriptionKnowledge(
    config=knowledge_config,
)

description_knowledge.build_knowledge_from_df(
    description_df, metadata.x_vocab
)
# Out:
# Preprocessing description words: 100%|████████████████████████| 2104/2104 [00:00<00:00, 10286.20it/s]

# %% [markdown]
# ## Genarate model

# %%
# load model
model = models.DescriptionModel()

# build model
model.build(metadata, description_knowledge)

# %% [markdown]
# ## Run Experiment

# %%
# train model
model.train_dataset(
    train_dataset,
    test_dataset,
    experiment_config.multilabel_classification,
    experiment_config.n_epochs,
)

# %%
# logging dataset info
mlflow.log_metric("train_size", len([x for x in train_dataset]))
mlflow.log_metric("test_size", len([x for x in test_dataset]))
mlflow.log_metric("x_vocab_size", len(metadata.x_vocab))
mlflow.log_metric("y_vocab_size", len(metadata.y_vocab))

# generate artifacts
# skip

# set mlflow tags
mlflow.set_tag("sequence_type", experiment_config.sequence_type)
mlflow.set_tag("model_type", experiment_config.model_type)
if len(metadata.y_vocab) == 1:
    mlflow.set_tag("task_type", "risk_prediction")
else:
    mlflow.set_tag("task_type", "sequence_prediction")

logging.info("Finished run %s", run_id)
